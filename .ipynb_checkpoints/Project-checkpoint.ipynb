# %% [markdown]
# # DSCI 100: Group Project
#
# ## Classification of Facebook Post Type Using Social Media Performance Metrics
#
# #### Introduction:
#
# The rapid advancement of technology has transformed the business world. Social media platforms have become the best place for businesses to advertise their brands by increasing customer engagement.
# Our report focuses on the most popular social network worldwide, Facebook, with over 2.7 billion monthly active users [1].
#
# The dataset *Facebook performance metrics* [2] contains data related to posts published throughout 2014 on a renowned cosmetics brand's Facebook page. Post information such as type (photo, status, link, or video), time posted (month, day, and hour), user engagement (comments, likes, and shares), impressions on each post, and whether the post was paid or unpaid is included in the dataset.
#
# This project uses all relevant columns from this dataset to determine the type of a brand's Facebook post. We determine which of these metrics are relevant in our cleaning and exploration of the data. We use our chosen predictors to build a prediction model using the K-nearest neighbour classification algorithm, implemented in the `tidymodels` framework, to predict the type of a post (photo, status, link, or video).

# %% [markdown]
# #### Preliminary exploratory data analysis:
#
# We begin by loading the relevant libraries.

# %%
# We include tidymodels for the KNN classification algorithm,
# and GGally for the ggpairs plotting function.
library(tidyverse)
library(repr)
library(tidymodels)
library(GGally)
library(knitr)

# %% [markdown]
# Next, we load the dataset:

# %%
# displays first and last 8 rows of the dataset
options(repr.matrix.max.rows = 16)
# Set the seed
set.seed(123)

# The original dataset was contained in a zip file which
# we extracted and pushed to a Github repository.
fb_data_raw <- read_csv2("https://gist.githubusercontent.com/KolCrooks/691e5890b6747b4777d6032f019b2c0f/raw/20629a5da3d5a7683e3071798876f3e4b204fbbb/fb_data.csv",  col_types = cols())
fb_data_raw
# Out:
# Using ',' as decimal and '.' as grouping mark. Use read_delim() for more control.
#     Page total likes Type   Category Post Month Post Weekday Post Hour Paid
# 1   139441           Photo  2        12         4             3        0
# 2   139441           Status 2        12         3            10        0
# 3   139441           Photo  3        12         3             3        0
# 4   139441           Photo  2        12         2            10        1
# 5   139441           Photo  2        12         2             3        0
# 6   139441           Status 2        12         1             9        0
# 7   139441           Photo  3        12         1             3        1
# 8   139441           Photo  3        12         7             9        1
# ⋮   ⋮                ⋮      ⋮        ⋮          ⋮            ⋮         ⋮
# 493 85979            Link   1        1          5            11         0
# 494 85093            Photo  3        1          1             2         0
# 495 85093            Photo  3        1          7            10         0
# 496 85093            Photo  3        1          7             2         0
# 497 81370            Photo  2        1          5             8         0
# 498 81370            Photo  1        1          5             2         0
# 499 81370            Photo  3        1          4            11         0
# 500 81370            Photo  2        1          4             4        NA
#     Lifetime Post Total Reach Lifetime Post Total Impressions
# 1    2752                      5091
# 2   10460                     19057
# 3    2413                      4373
# 4   50128                     87991
# 5    7244                     13594
# 6   10472                     20849
# 7   11692                     19479
# 8   13720                     24137
# ⋮   ⋮                         ⋮
# 493 45920                      5808
# 494  8412                     13960
# 495  5400                      9218
# 496  4684                      7536
# 497  3480                      6229
# 498  3778                      7216
# 499  4156                      7564
# 500  4188                      7292
#     Lifetime Engaged Users Lifetime Post Consumers Lifetime Post Consumptions
# 1    178                    109                     159
# 2   1457                   1361                    1674
# 3    177                    113                     154
# 4   2211                    790                    1119
# 5    671                    410                     580
# 6   1191                   1073                    1389
# 7    481                    265                     364
# 8    537                    232                     305
# ⋮   ⋮                      ⋮                       ⋮
# 493  753                    655                     763
# 494 1179                   1111                    1632
# 495  810                    756                    1003
# 496  733                    708                     985
# 497  537                    508                     687
# 498  625                    572                     795
# 499  626                    574                     832
# 500  564                    524                     743
#     Lifetime Post Impressions by people who have liked your Page
# 1    3078
# 2   11710
# 3    2812
# 4   61027
# 5    6228
# 6   16034
# 7   15432
# 8   19728
# ⋮   ⋮
# 493 15766
# 494  8632
# 495  5654
# 496  4750
# 497  3961
# 498  4742
# 499  4534
# 500  3861
#     Lifetime Post reach by people who like your Page
# 1    1640
# 2    6112
# 3    1503
# 4   32048
# 5    3200
# 6    7852
# 7    9328
# 8   11056
# ⋮   ⋮
# 493 10720
# 494  5348
# 495  3230
# 496  2876
# 497  2104
# 498  2388
# 499  2452
# 500  2200
#     Lifetime People who have liked your Page and engaged with your post comment
# 1    119                                                                 4
# 2   1108                                                                 5
# 3    132                                                                 0
# 4   1386                                                                58
# 5    396                                                                19
# 6   1016                                                                 1
# 7    379                                                                 3
# 8    422                                                                 0
# ⋮   ⋮                                                                   ⋮
# 493 220                                                                  0
# 494 699                                                                 17
# 495 422                                                                 10
# 496 392                                                                  5
# 497 301                                                                  0
# 498 363                                                                  4
# 499 370                                                                  7
# 500 316                                                                  0
#     like share Total Interactions
# 1     79  17    100
# 2    130  29    164
# 3     66  14     80
# 4   1572 147   1777
# 5    325  49    393
# 6    152  33    186
# 7    249  27    279
# 8    325  14    339
# ⋮   ⋮    ⋮     ⋮
# 493 128   9    137
# 494 185  55    257
# 495 125  41    176
# 496  53  26     84
# 497  53  22     75
# 498  93  18    115
# 499  91  38    136
# 500  91  28    119

# %% [markdown]
# The data is already in tidy format. The column headings were made more usable by removing spaces and shortening longer headings. Secondly, we set our target variable, `type`, as a factor.

# %%
# Clean the data, change column names, and convert some columns to factors:
fb_data_clean_cols <- fb_data_raw
colnames(fb_data_clean_cols) <- c("page_likes", "type", "category", "post_month", "post_weekday", "post_hour", "paid", "reach", 
      "impressions", "engaged_users", "post_consumers", "post_consumptions", "impressions_by_people_that_liked_page", 
      "reach_by_people_that_like_page", "people_liked_and_engaged", "comments", "likes", "shares", "interactions")
fb_data_clean <- fb_data_clean_cols %>% 
        mutate(type = as_factor(type))

fb_data_clean
# Out:
#     page_likes type   category post_month post_weekday post_hour paid reach
# 1   139441     Photo  2        12         4             3        0     2752
# 2   139441     Status 2        12         3            10        0    10460
# 3   139441     Photo  3        12         3             3        0     2413
# 4   139441     Photo  2        12         2            10        1    50128
# 5   139441     Photo  2        12         2             3        0     7244
# 6   139441     Status 2        12         1             9        0    10472
# 7   139441     Photo  3        12         1             3        1    11692
# 8   139441     Photo  3        12         7             9        1    13720
# ⋮   ⋮          ⋮      ⋮        ⋮          ⋮            ⋮         ⋮    ⋮
# 493 85979      Link   1        1          5            11         0   45920
# 494 85093      Photo  3        1          1             2         0    8412
# 495 85093      Photo  3        1          7            10         0    5400
# 496 85093      Photo  3        1          7             2         0    4684
# 497 81370      Photo  2        1          5             8         0    3480
# 498 81370      Photo  1        1          5             2         0    3778
# 499 81370      Photo  3        1          4            11         0    4156
# 500 81370      Photo  2        1          4             4        NA    4188
#     impressions engaged_users post_consumers post_consumptions
# 1    5091        178           109            159
# 2   19057       1457          1361           1674
# 3    4373        177           113            154
# 4   87991       2211           790           1119
# 5   13594        671           410            580
# 6   20849       1191          1073           1389
# 7   19479        481           265            364
# 8   24137        537           232            305
# ⋮   ⋮           ⋮             ⋮              ⋮
# 493  5808        753           655            763
# 494 13960       1179          1111           1632
# 495  9218        810           756           1003
# 496  7536        733           708            985
# 497  6229        537           508            687
# 498  7216        625           572            795
# 499  7564        626           574            832
# 500  7292        564           524            743
#     impressions_by_people_that_liked_page reach_by_people_that_like_page
# 1    3078                                  1640
# 2   11710                                  6112
# 3    2812                                  1503
# 4   61027                                 32048
# 5    6228                                  3200
# 6   16034                                  7852
# 7   15432                                  9328
# 8   19728                                 11056
# ⋮   ⋮                                     ⋮
# 493 15766                                 10720
# 494  8632                                  5348
# 495  5654                                  3230
# 496  4750                                  2876
# 497  3961                                  2104
# 498  4742                                  2388
# 499  4534                                  2452
# 500  3861                                  2200
#     people_liked_and_engaged comments likes shares interactions
# 1    119                      4         79   17     100
# 2   1108                      5        130   29     164
# 3    132                      0         66   14      80
# 4   1386                     58       1572  147    1777
# 5    396                     19        325   49     393
# 6   1016                      1        152   33     186
# 7    379                      3        249   27     279
# 8    422                      0        325   14     339
# ⋮   ⋮                        ⋮        ⋮     ⋮      ⋮
# 493 220                       0       128    9     137
# 494 699                      17       185   55     257
# 495 422                      10       125   41     176
# 496 392                       5        53   26      84
# 497 301                       0        53   22      75
# 498 363                       4        93   18     115
# 499 370                       7        91   38     136
# 500 316                       0        91   28     119

# %% [markdown]
# We suspect that the `comments`, `likes`, and `shares` columns should be useful as predictors, but the scale is such that it is hard to see any significant differences. Since the `interactions` column simply gives the total of all three interaction types, we convert each of these columns to a ratio of total interactions. This standardization of the data will allow a more meaningful comparison than their raw values, as the raw values are more a measure of overall popularity of the page, and are not themselves characteristic of the post type. This also allows us to eliminate the `interactions` column as a potential standalone predictor.
#
# Similarly, we will add a column called `engagement ratio`. It does not seem valuable to compare the `reach` - which counts the number of appearances on a user's facebook page - of a post, as this does not indicate their interaction with it. We instead will calculate the `engagement ratio` as `interactions` over `reach`; this gives the ratio of total reached users who actually *interacted* with a post [3].
#
# After our mutations, we count the instances of missing data.

# %%
fb_data_mutated <- fb_data_clean %>%  
            mutate(comment_ratio = comments / interactions) %>% 
            mutate(like_ratio = likes / interactions) %>% 
            mutate(share_ratio = shares / interactions) %>% 
            mutate(engagement_ratio = interactions / reach) %>%
            select(-comments, -likes, -shares, -interactions)

# NA rows:
sum(is.na(fb_data_mutated))
# Out:
# [1] 22

# %% [markdown]
# We use the `na.omit` function to remove the missing data.

# %%
fb_data_mutated <- fb_data_mutated %>% 
    na.omit()

# NA rows:
sum(is.na(fb_data_mutated))
# Out:
# [1] 0

# %% [markdown]
# Here, we split our data set into a training set and a testing set using the `initial_split` function. We do this so that we can train our KNN classifier using only the training set; then, to evaluate the accuracy of the classifier, we can use it to predict the posts' types (which we know) of the testing set. In order to train a more accurate model while still having an accurate evaluation of its performance, we allocate 75% of our data for training and reserve 25% for testing. As we want to classify post type as our target variable, we pass `type` as the `strata` argument in `initial_split`.

# %%
# Split the data:
fb_split <- initial_split(fb_data_mutated, prop = 0.75, strata = type)
fb_train <- training(fb_split)
fb_test <- testing(fb_split)

# ensure fb_train and fb_test contain 75% and 25% of data, respectively
nrow(fb_train)
nrow(fb_test)
# Out:
# [1] 368
# [1] 122

# %% [markdown]
# #### Selecting our predictors:
#
# To figure out which predictors to use in our classification algorithm, we use `ggpairs` to determine how well each column can predict post type. This will create a boxplot for each potential predictor and type, which we will compare to choose predictors.  Before doing this, we will remove the columns that we know will not work; this will reduce clutter in the plot while allowing us to more accurately compare the remaining predictors.
#
# The columns we know we cannot use as predictors are the categorical data: the time-based columns `post_month`, `post_weekday`, and `post_hour`, and the columns `category` and `paid`. We perform these adjustments below:

# %%
# Columns before selection
colnames(fb_train)
# Out:
#  [1] "page_likes"
#  [2] "type"
#  [3] "category"
#  [4] "post_month"
#  [5] "post_weekday"
#  [6] "post_hour"
#  [7] "paid"
#  [8] "reach"
#  [9] "impressions"
# [10] "engaged_users"
# [11] "post_consumers"
# [12] "post_consumptions"
# [13] "impressions_by_people_that_liked_page"
# [14] "reach_by_people_that_like_page"
# [15] "people_liked_and_engaged"
# [16] "comment_ratio"
# [17] "like_ratio"
# [18] "share_ratio"
# [19] "engagement_ratio"

# %%
fb_train_selected1 <- fb_train %>% 
            select(-post_month, -post_weekday, -post_hour, -category, -paid) %>%
            select(type, page_likes, reach:engagement_ratio) # reorder the df so that type is first, so that we can display only that row

# Columns after selection
colnames(fb_train_selected1)
# Out:
#  [1] "type"
#  [2] "page_likes"
#  [3] "reach"
#  [4] "impressions"
#  [5] "engaged_users"
#  [6] "post_consumers"
#  [7] "post_consumptions"
#  [8] "impressions_by_people_that_liked_page"
#  [9] "reach_by_people_that_like_page"
# [10] "people_liked_and_engaged"
# [11] "comment_ratio"
# [12] "like_ratio"
# [13] "share_ratio"
# [14] "engagement_ratio"

# %% [markdown]
# We create the ggpairs visualizations in the following cell, splitting the columns into two segments to improve plot readability.

# %%
options(repr.plot.height = 6, repr.plot.width = 30)
fb_select_plot1_first <- fb_train_selected1 %>%
    select(type:post_consumptions) %>% 
    ggpairs() +
    ggtitle("Figure 1: Distribution of first six column variables for each type of post, before elimination of potential predictors") +
    theme(text = element_text(size=20),
            axis.text.x = element_text(angle = 90, hjust = 1))

fb_select_plot1_second <- fb_train_selected1 %>%
    select(type, impressions_by_people_that_liked_page:engagement_ratio) %>% 
    ggpairs() +
    ggtitle("Figure 2: Distribution of remaining seven column variables for each type of post, before elimination of potential predictors") +
    theme(text = element_text(size=20),
            axis.text.x = element_text(angle = 90, hjust = 1))

# Select just the top row of each plot because it is the only thing that we are trying to compare
fb_select_plot1_first$nrow <- 1
fb_select_plot1_first$yAxisLabels <- fb_select_plot1_first$yAxisLabels[1]
fb_select_plot1_first

fb_select_plot1_second$nrow <- 1
fb_select_plot1_second$yAxisLabels <- fb_select_plot1_second$yAxisLabels[1]
fb_select_plot1_second
# Out:
# plot without title
# plot without title

# %% [markdown]
# With this plot, we can begin to analyze which predictors may or may not be good classifiers for our target variable. We want to avoid using predictors that have minimal variability within each type, and those which have a high level of overlap between types.
# - we eliminate `page_likes` because this column measures the total likes of the facebook page at the time a post was published, and is not necessarily related to any specific post.
# - similarly, we eliminate `reach` as this column is simply the number of users for whom the post showed up on their facebook feed, and sheds no light on how the user may have interacted with the post.
# - we eliminate `impressions` because the difference of the boxes in the first three types look the same, meaning there is low variation in the data. While the boxplot for videos does look different from the rest, the many outliers of the boxplot of photos occupy similar space.
# - we will keep only one of `engaged_users`, `post_consumers`, and `post_consumptions`. This is because they all effectively measure the same variable, in a slightly different way: `engaged_users` is the number of *unique* users that clicked in a post; `post_consumers` is the *total* number of people that clicked in a post; `post_consumptions` is the total number of *clicks* in a post. We will keep `post_consumptions` as a predictor and eliminate the other two, as this variable is more indicative of post type; from the boxplot, it appears that with photos in particular, users may return to the post and continue interacting after the initial view. We want to include this data in our classifier, as it should help with classification.
# - we eliminate `impressions_by_people_that_liked_page`, as each box plot is essentially a vertical line.

# %%
# we remove the eliminated columns.
fb_train_selected2 <- fb_train_selected1 %>% 
            select(-page_likes, -reach, -impressions, -engaged_users, -post_consumers, -impressions_by_people_that_liked_page)

# %% [markdown]
# We again use the ggpairs function to observe boxplots of the remaining potential predictors:

# %%
options(repr.plot.height = 6, repr.plot.width = 30)
fb_select_plot2_first <- fb_train_selected2 %>%
    select(type:people_liked_and_engaged) %>% 
    ggpairs() +
    ggtitle("Figure 3: Distribution of first three column variables for each type of post, after elimination of ineffective predictors") +
    theme(text = element_text(size=20),
        axis.text.x = element_text(angle = 90, hjust = 1))

fb_select_plot2_second <- fb_train_selected2 %>% 
    select(type, comment_ratio:engagement_ratio) %>% 
    ggpairs() +
    ggtitle("Figure 4: Distribution of remaining four column variables for each type of post, after elimination of ineffective predictors") +
    theme(text = element_text(size=20),
        axis.text.x = element_text(angle = 90, hjust = 1))

# Select just the top row of each plot, because it is the only thing that we are trying to compare
fb_select_plot2_first$nrow <- 1
fb_select_plot2_first$yAxisLabels <- fb_select_plot2_first$yAxisLabels[1]
fb_select_plot2_first

fb_select_plot2_second$nrow <- 1
fb_select_plot2_second$yAxisLabels <- fb_select_plot2_second$yAxisLabels[1]
fb_select_plot2_second
# Out:
# plot without title
# plot without title

# %% [markdown]
# As seen in the plots above, `comment_ratio` does not appear that it would be a great predictor, as there is a lot of overlap between post types and not a lot of variability within post types. But, `like_ratio`, and `share_ratio` appear to be useful, as the variance in and between each plot is higher. We remove `comment_ratio` as a predictor:

# %%
fb_train_selected_final <- fb_train_selected2 %>% 
            select(-comment_ratio)

# %% [markdown]
# Now, our training set contains the following 7 columns:

# %%
colnames(fb_train_selected_final)
# Out:
# [1] "type"                           "post_consumptions"
# [3] "reach_by_people_that_like_page" "people_liked_and_engaged"
# [5] "like_ratio"                     "share_ratio"
# [7] "engagement_ratio"

# %% [markdown]
# #### Creating the model:
#
# Our model will use the following input columns of the original dataset: `type` as the target variable, and `post_consumptions`, `reach_by_people_that_like_page`, and `people_liked_and_engaged` as predictors. We will also be using the generated columns `like_ratio`, `share_ratio`, and `engagement_ratio` as predictors.
#
# First, a table was constructed to gain a necessary summary of the training data. Table 1 groups posts by type and computes the total of each.

# %%
summary_table1 <- fb_train_selected_final %>% 
    group_by(type) %>%
    summarize(`total of type` = n(), .groups="keep") %>% 
    kable("simple", caption = "1: Total counts of each post type in training data set")

summary_table1
# Out:
# Table: 1: Total counts of each post type in training data set
#
# type      total of type
# -------  --------------
# Photo               316
# Status               33
# Link                 15
# Video                 4

# %% [markdown]
# Looking at the number of each type of post, it is clear that we have a *class imbalance* in our training data. If we do not fix this imbalance, since there is a much higher number of photos in the data than any other post type, we are much more likely to choose neighbours that are photos when using the KNN classification algorithm. This does raise some concerns about how well our model will be able to predict type (namely, posts that are of type `video`, with few observations), but we will attempt to maximize the accuracy of our results, and minimize overfitting. We use *upsampling*, to make the number of observations of each type equal to that of the majority type.

# %%
upsample_recipe <- recipe(type ~ ., data = fb_train_selected_final) %>% 
                    step_upsample(type, over_ratio = 1, skip = FALSE ) %>% 
                    prep()
upsample_recipe

fb_train_upsampled <- upsample_recipe %>% bake(fb_train_selected_final)
# Out:
# Data Recipe
#
# Inputs:
#
#       role #variables
#    outcome          1
#  predictor          6
#
# Training data contained 368 data points and no missing data.
#
# Operations:
#
# Up-sampling based on type [trained]

# %%
summary_table2 = fb_train_upsampled %>% 
    group_by(type) %>%
    summarize(total_of_type = n(), .groups="keep") %>% 
    kable("simple", caption = "2: Total counts of each post type in training data set after upsampling")
summary_table2
# Out:
# Table: 2: Total counts of each post type in training data set after upsampling
#
# type      total_of_type
# -------  --------------
# Photo               316
# Status              316
# Link                316
# Video               316

# %% [markdown]
# Now that the class imbalance has been fixed, we can proceed with creating our classification model. In the following cell, we create the model recipe. We will attempt to predict `type` from all columns we have left in our data frame as predictors. We include `step_scale` and `step_center` to center and scale the data as good practice, to ensure that no variable which may be on a larger scale than another will dominate the predictions. The `prep` functions is used to compute anything necessary to run the recipe, e.g., the data's column means and standard deviations.

# %%
# Create the recipe
fb_recipe <- recipe(type ~ post_consumptions + 
                           reach_by_people_that_like_page +
                           people_liked_and_engaged +
                           like_ratio +
                           share_ratio +
                           engagement_ratio,
                data = fb_train_upsampled) %>%
                step_scale(all_predictors()) %>% 
                step_center(all_predictors()) %>% 
                prep()
                
fb_recipe

colnames(fb_train_upsampled)
# Out:
# Data Recipe
#
# Inputs:
#
#       role #variables
#    outcome          1
#  predictor          6
#
# Training data contained 1264 data points and no missing data.
#
# Operations:
#
# Scaling for 6 items [trained]
# Centering for 6 items [trained]
# [1] "post_consumptions"              "reach_by_people_that_like_page"
# [3] "people_liked_and_engaged"       "like_ratio"
# [5] "share_ratio"                    "engagement_ratio"
# [7] "type"

# %% [markdown]
# We use `bake` to apply the recipe, to ensure that our changes have been applied:

# %%
baked_fb <- bake(fb_recipe, fb_train_upsampled)
baked_fb
# Out:
#      post_consumptions reach_by_people_that_like_page people_liked_and_engaged
# 1    -0.8823513        -0.99237032                    -0.9220620
# 2    -0.8847530        -1.00710558                    -0.9071796
# 3    -0.7838813        -0.16547480                    -0.6244132
# 4    -0.8122215         0.02038309                    -0.5751866
# 5    -0.8386402        -0.91880157                    -0.8304778
# 6    -0.8890761        -0.93493507                    -0.8694011
# 7    -0.8780283        -0.96257713                    -0.8487946
# 8    -0.7584232         0.90837079                    -0.2752482
# ⋮    ⋮                 ⋮                              ⋮
# 1257  2.5607369        0.2208687                       1.48087996
# 1258  0.1609505        0.8619063                      -0.04514274
# 1259  0.1609505        0.8619063                      -0.04514274
# 1260  0.1729591        2.9958302                       0.09566805
# 1261  0.1609505        0.8619063                      -0.04514274
# 1262  2.5607369        0.2208687                       1.48087996
# 1263 -0.1286954        0.3490762                      -0.41834860
# 1264 -0.1286954        0.3490762                      -0.41834860
#      like_ratio  share_ratio engagement_ratio type
# 1    -0.02701321  0.2058607  1.7461514        Photo
# 2     0.35295326  0.2800814  1.4944319        Photo
# 3     1.08545390 -0.8811136  0.7597603        Photo
# 4     1.80444758 -1.7046110  0.8266532        Photo
# 5     0.03567744  0.4002981  1.2649387        Photo
# 6     0.40928252  0.2030599  1.5662241        Photo
# 7     1.18145157 -1.3410551  3.5880345        Photo
# 8     1.85406095 -1.8220127  0.9517377        Photo
# ⋮    ⋮           ⋮           ⋮                ⋮
# 1257 -0.2422789   0.44068126  0.3515351       Video
# 1258  0.2591953  -0.05053810 -0.6954945       Video
# 1259  0.2591953  -0.05053810 -0.6954945       Video
# 1260 -0.4312158   0.09247557 -0.9729196       Video
# 1261  0.2591953  -0.05053810 -0.6954945       Video
# 1262 -0.2422789   0.44068126  0.3515351       Video
# 1263  0.3186377  -1.20859834 -0.7470895       Video
# 1264  0.3186377  -1.20859834 -0.7470895       Video

# %% [markdown]
# We use the `knn_spec` function to create our *model specification*. We specify the `neighbours` parameter as `tune()`, a `tidymodels` function which will choose the value of K that gives the highest accuracy. The other parameters are typical of the KNN classification algorithm.

# %%
# Create the tune spec
knn_spec_tune <- nearest_neighbor(weight_func = "rectangular", neighbors = tune()) %>% 
            set_engine("kknn") %>% 
            set_mode("classification")

# %% [markdown]
# Since we are attempting to tune our model for highest accuracy, we use *cross-validation*. We do this using the `vfold_cv` function from `tidymodels`; this method splits our overall training data up in different ways, trains and evaluates a classifier for each split, and chooses the best value of K based on all of the different results. This is useful because if we split the data only once, the choice of best parameter value will be influenced by whatever data is "lucky" enough to end up in the validation set.
#
# We pass in the `baked_fb` data set from above, and instruct the model to use 10 "folds". Generally, a higher number of folds will yield a more accurate parameter value, but the computation will take longer. We choose 10 as this is the upper bound on typical values for `v`.

# %%
# Create vfolds with v
fb_vfold <- vfold_cv(baked_fb, v = 10, strata = type)

# %% [markdown]
# We combine the recipe and model specification into a workflow using the following code. The `tune_grid` function is used to fit the model for each value in a range; we have given it a sequence of possible parameter values from 1 to 10. We use the `collect_metrics` function to aggregate the mean and standard error across the folds.

# %%
gridvals = tibble(neighbors = 1:10)

fb_fit <- workflow() %>% 
        add_recipe(fb_recipe) %>% 
        add_model(knn_spec_tune) %>% 
        tune_grid(resamples = fb_vfold, grid = gridvals) %>% 
        collect_metrics()

fb_fit
# Out:
#    neighbors .metric  .estimator mean      n  std_err     .config
# 1  1         accuracy multiclass 0.9889365 10 0.003167894 Model01
# 2  1         roc_auc  hand_till  0.9926243 10 0.002111929 Model01
# 3  2         accuracy multiclass 0.9889365 10 0.003167894 Model02
# 4  2         roc_auc  hand_till  0.9926243 10 0.002111929 Model02
# 5  3         accuracy multiclass 0.9794355 10 0.003780279 Model03
# 6  3         roc_auc  hand_till  0.9926243 10 0.002111929 Model03
# 7  4         accuracy multiclass 0.9794355 10 0.003780279 Model04
# 8  4         roc_auc  hand_till  0.9925593 10 0.002124448 Model04
# ⋮  ⋮         ⋮        ⋮          ⋮         ⋮  ⋮           ⋮
# 13  7        accuracy multiclass 0.9580393 10 0.004808785 Model07
# 14  7        roc_auc  hand_till  0.9931881 10 0.002021268 Model07
# 15  8        accuracy multiclass 0.9580393 10 0.004808785 Model08
# 16  8        roc_auc  hand_till  0.9928869 10 0.002048450 Model08
# 17  9        accuracy multiclass 0.9453125 10 0.007189015 Model09
# 18  9        roc_auc  hand_till  0.9927291 10 0.002107796 Model09
# 19 10        accuracy multiclass 0.9453125 10 0.007189015 Model10
# 20 10        roc_auc  hand_till  0.9923571 10 0.002154196 Model10

# %% [markdown]
# By filtering for accuracy and taking the mean of each parameter value, we create a plot of accuracy vs. value of K:

# %%
fb_filtered <- fb_fit %>% filter(.metric == "accuracy")

fb_filtered %>% ggplot(aes(x = neighbors, y = mean)) +
            geom_point() +
            geom_line() +
            labs(y = "Mean accuracy", x = "Number of neighbours") +
            ggtitle("Figure 5: Mean accuracy of classification model for each tested value of K neighbours, from one to ten") +
            theme(text = element_text(size=18)) +
            scale_x_continuous(breaks = 1:10)
# Out:
# plot without title

# %% [markdown]
# From this plot, we see that $K = 2$ is the value of K which yields the highest accuracy. We create a new model specification, this time using the chosen parameter value as the `neighbours` argument. We again combine the previous steps into a workflow, but this time we use the `fit` function instead of `tune_grid` to fit the model to our training data.

# %%
knn_spec <- nearest_neighbor(weight_func = "rectangular", neighbors = 2) %>%
  set_engine("kknn") %>%
  set_mode("classification")

knn_fit <- workflow() %>%
  add_recipe(fb_recipe) %>%
  add_model(knn_spec) %>%
  fit(data = baked_fb)
knn_fit
# Out:
# ══ Workflow [trained] ══════════════════════════════════════════════════════════
# Preprocessor: Recipe
# Model: nearest_neighbor()
#
# ── Preprocessor ────────────────────────────────────────────────────────────────
# 2 Recipe Steps
#
# ● step_scale()
# ● step_center()
#
# ── Model ───────────────────────────────────────────────────────────────────────
#
# Call:
# kknn::train.kknn(formula = ..y ~ ., data = data, ks = ~2, kernel = ~"rectangular")
#
# Type of response variable: nominal
# Minimal misclassification: 0.01028481
# Best kernel: rectangular
# Best k: 2

# %% [markdown]
# Finally, we use the `predict` function to apply our classification model to our testing set! We use `bind_cols` to append the predicted columns to our testing data set, and in the following cell, we obtain the metrics of our predictions compared to our actual posts' types.

# %%
fb_predictions <- predict(knn_fit, fb_test) %>%
  bind_cols(fb_test)
fb_predictions
# Out:
#     .pred_class page_likes type   category post_month post_weekday post_hour
# 1   Photo       139441     Photo  2        12         2            10
# 2   Photo       139441     Photo  2        12         2             3
# 3   Photo       139441     Status 2        12         5            10
# 4   Photo       139441     Photo  2        12         5            10
# 5   Photo       138414     Status 2        12         3            10
# 6   Photo       138414     Photo  3        12         1            11
# 7   Photo       138414     Link   1        12         7            10
# 8   Photo       138458     Status 2        12         6             3
# ⋮   ⋮           ⋮          ⋮      ⋮        ⋮          ⋮            ⋮
# 115 Photo       93042      Photo  3        2          3            13
# 116 Photo       92721      Photo  3        2          2            13
# 117 Photo       92079      Photo  1        2          6            13
# 118 Photo       91972      Photo  3        2          6             3
# 119 Photo       86909      Photo  3        1          6            16
# 120 Photo       86491      Link   1        1          2             2
# 121 Photo       85979      Photo  3        1          1            12
# 122 Photo       85979      Link   1        1          5            11
#     paid reach  impressions engaged_users post_consumers post_consumptions
# 1   1    50128  87991       2211           790           1119
# 2   0     7244  13594        671           410            580
# 3   0    21744  42334       4258          4100           4540
# 4   0     2847   5133        193           115            133
# 5   0    10060  19680       1264          1209           1425
# 6   0     1591   2825        121            88            111
# 7   0     3454   6853        118           104            130
# 8   0     8284  15104       1521          1462           1711
# ⋮   ⋮    ⋮      ⋮           ⋮             ⋮              ⋮
# 115 0      8500  14157      1095          1029           1422
# 116 0      7228  12627      1239          1189           1612
# 117 0    158208 453213      2482          2319           3412
# 118 0      6484  10832      1166          1115           1441
# 119 1      5754   9238      1179          1143           1452
# 120 0      5168   8371        66            59             71
# 121 0      5034   8030      1020           993           1243
# 122 0     45920   5808       753           655            763
#     impressions_by_people_that_liked_page reach_by_people_that_like_page
# 1   61027                                 32048
# 2    6228                                  3200
# 3   37849                                 18952
# 4    3779                                  2072
# 5   17272                                  8548
# 6    2116                                  1161
# 7    6282                                  3100
# 8   10266                                  5372
# ⋮   ⋮                                     ⋮
# 115  9670                                  5640
# 116  9781                                  5348
# 117 81938                                 20608
# 118  7316                                  4280
# 119  6101                                  3546
# 120  7041                                  3996
# 121  5340                                  3094
# 122 15766                                 10720
#     people_liked_and_engaged comment_ratio like_ratio share_ratio
# 1   1386                     0.03263928    0.8846370  0.08272369
# 2    396                     0.04834606    0.8269720  0.12468193
# 3   3798                     0.00000000    0.9246032  0.07539683
# 4    152                     0.00000000    0.8653846  0.13461538
# 5   1162                     0.03703704    0.7962963  0.16666667
# 6    100                     0.00000000    0.8095238  0.19047619
# 7    106                     0.00000000    0.8888889  0.11111111
# 8   1200                     0.00000000    0.8301887  0.16981132
# ⋮   ⋮                        ⋮             ⋮          ⋮
# 115  465                     0.02304147    0.7327189  0.24423963
# 116  606                     0.03030303    0.7757576  0.19393939
# 117 1034                     0.02875399    0.8562300  0.11501597
# 118  583                     0.02352941    0.7529412  0.22352941
# 119  420                     0.00000000    0.7738095  0.22619048
# 120   58                     0.00000000    0.8571429  0.14285714
# 121  440                     0.02409639    0.6746988  0.30120482
# 122  220                     0.00000000    0.9343066  0.06569343
#     engagement_ratio
# 1   0.035449250
# 2   0.054251795
# 3   0.011589404
# 4   0.036529680
# 5   0.010735586
# 6   0.026398492
# 7   0.005211349
# 8   0.012795751
# ⋮   ⋮
# 115 0.025529412
# 116 0.022827892
# 117 0.001978408
# 118 0.026218384
# 119 0.014598540
# 120 0.002708978
# 121 0.016487882
# 122 0.002983449

# %%
fb_prediction_accuracy <- fb_predictions %>%
  metrics(truth = type, estimate = .pred_class) %>% 
    kable("simple", caption = "3: Metrics for model when applied to testing data set")

fb_prediction_accuracy
# Out:
# Table: 3: Metrics for model when applied to testing data set
#
# .metric    .estimator    .estimate
# ---------  -----------  ----------
# accuracy   multiclass    0.8196721
# kap        multiclass    0.0000000

# %% [markdown]
# The accuracy of the model when predicting on the test set is around 80%. We can further examine our results by creating a *confusion matrix* for the classifier; the columns represent the actual type of a post, while the rows represent the predicted type. We use the `conf_mat` function to create this matrix:

# %%
fb_type_mat <- fb_predictions %>% 
    conf_mat(truth = type, estimate = .pred_class)

print("Figure 6: Confusion matrix of results of classification on testing data set. Values along the diagonal indicate the number of true positives.")
fb_type_mat
# Out:
# [1] "Figure 6: Confusion matrix of results of classification on testing data set. Values along the diagonal indicate the number of true positives."
#           Truth
# Prediction Photo Status Link Video
#     Photo    100     12    7     3
#     Status     0      0    0     0
#     Link       0      0    0     0
#     Video      0      0    0     0

# %%
# percentage of posts in fb_test_selected_final that are photos
photos_percentage <- nrow(fb_test %>% filter(type == "Photo")) / nrow(fb_test) * 100

print("Percentage of testing data that are actually photos:")
photos_percentage
# Out:
# [1] "Percentage of testing data that are actually photos:"
# [1] 81.96721

# %% [markdown]
# With this visualization, it becomes apparent that our classifier predicted every post to be a photo. This is not an ideal outcome, but explains why we achieved a prediction accuracy of around 80%. The vast majority of posts in the data set, and thus in both the training and the testing set, were actually photos. Because of this, despite the oversampling performed, photo was predicted as the type 100% of the time, yielding the correct result *approximately* 80% of the time.

# %% [markdown]
# ### Discussion:
#
# In our analysis, we hoped to define a relationship between the predictors that we selected, and the type of the post. Based on the results, we were somewhat unsuccessful in this.
#
# A model accuracy of 80% sounds promising, but this is merely a result of the testing set containing the same percentage of photos. This is because the model we created is overfitted and produces "Photo" as every result. We knew this could be a problem from initial data exploration, but were hoping it could be reduced by upsampling the data. This proved ineffective; to fix the problem with the model, we would have to try a different method of reducing overfitting.
#
# We were hoping that this model would be able to show some relationships between the metrics a post generates, and the type of that post. With an accurate model, companies would be able to create tailored posts that achieve specific target engagement. For example, if it was found that high likes and general engagement were characteristic of videos, companies may decide to focus on video-based posts.
#
# Other questions that may be posed regarding this data include:
# - Do paid posts generate more traffic than unpaid posts?
# - Does the category of a post (i.e., “action”, “product”, or “inspiration” classification) affect the overall and/or ratio of interactions on a post?
# - Do posts with more interactions overall correlate with increases in users liking a company’s Facebook page?

# %% [markdown]
# ### References:
# [1] Statista, "Global social networks ranked by number of users 2021", 2021 [Online]. Available: https://www-statista-com.ezproxy.library.ubc.ca/statistics/272014/global-social-networks-ranked-by-number-of-users/. [Accessed: 28- Feb- 2021]
#
# [2] S. Moro, P. Rita and B. Vala, "Predicting social media performance metrics and evluation of the impact on brand building: A data mining approach", *Journal of Business Research*, vol. 69, no. 9, 2021.
#
# [3] E. Ernoult, “6 Facebook Metrics Marketers Should Be Measuring : Social Media Examiner,” Social Media Examiner | Social Media Marketing. [Online]. Available: https://www.socialmediaexaminer.com/facebook-page-metrics/. [Accessed: 12-Apr-2021].
